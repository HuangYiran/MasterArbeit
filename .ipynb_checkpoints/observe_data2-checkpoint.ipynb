# %% [markdown]
# 这个文件，主要用于观察数据和提取(sid, score)。提取数据部分内容集中在最后四个block中。主要实现了列提取，按sida

# %%
data = read.table("./test_data/ad-ende-good-stnd.csv", header = TRUE)
data
# Out:
#       HITId WorkerId                                    Input.src Input.trg
# 1     1759  chanberg_chantal.amrhein@uzh.ch             en        de
# 2     1768  lmu-simon_riess.simon@yahoo.de              en        de
# 3     1768  lmu-simon_riess.simon@yahoo.de              en        de
# 4     1768  lmu-simon_riess.simon@yahoo.de              en        de
# 5     1768  lmu-simon_riess.simon@yahoo.de              en        de
# 6     1768  lmu-simon_riess.simon@yahoo.de              en        de
# 7     1775  lmu-simon_riess.simon@yahoo.de              en        de
# 8     1775  lmu-simon_riess.simon@yahoo.de              en        de
# 9     1775  lmu-simon_riess.simon@yahoo.de              en        de
# 10    1782  cfedermann_cfedermann@gmail.com             en        de
# 11    1782  cfedermann_cfedermann@gmail.com             en        de
# 12    1782  cfedermann_cfedermann@gmail.com             en        de
# 13    1775  lmu-simon_riess.simon@yahoo.de              en        de
# 14    1775  lmu-simon_riess.simon@yahoo.de              en        de
# 15    1775  lmu-simon_riess.simon@yahoo.de              en        de
# 16    1775  lmu-simon_riess.simon@yahoo.de              en        de
# 17    1775  lmu-simon_riess.simon@yahoo.de              en        de
# 18    1759  chanberg_chantal.amrhein@uzh.ch             en        de
# 19    1796  UE_Caelan_dark1thought@hotmail.co.uk        en        de
# 20    1796  UE_Caelan_dark1thought@hotmail.co.uk        en        de
# 21    1796  UE_Caelan_dark1thought@hotmail.co.uk        en        de
# 22    1803  petra.grycova_grpet@seznam.cz               en        de
# 23    1803  petra.grycova_grpet@seznam.cz               en        de
# 24    1803  petra.grycova_grpet@seznam.cz               en        de
# 25    1803  petra.grycova_grpet@seznam.cz               en        de
# 26    1803  petra.grycova_grpet@seznam.cz               en        de
# 27    1803  petra.grycova_grpet@seznam.cz               en        de
# 28    1803  petra.grycova_grpet@seznam.cz               en        de
# 29    1803  petra.grycova_grpet@seznam.cz               en        de
# 30    1803  petra.grycova_grpet@seznam.cz               en        de
# ⋮     ⋮     ⋮                                           ⋮         ⋮
# 11871 5430  guta_guta@cs.rwth-aachen.de                 en        de
# 11872 5430  guta_guta@cs.rwth-aachen.de                 en        de
# 11873 5431  lmu-simon_riess.simon@yahoo.de              en        de
# 11874 5431  lmu-simon_riess.simon@yahoo.de              en        de
# 11875 5431  guta_guta@cs.rwth-aachen.de                 en        de
# 11876 5431  guta_guta@cs.rwth-aachen.de                 en        de
# 11877 5431  lmu-simon_riess.simon@yahoo.de              en        de
# 11878 5431  lmu-simon_riess.simon@yahoo.de              en        de
# 11879 5431  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11880 5431  guta_guta@cs.rwth-aachen.de                 en        de
# 11881 5431  guta_guta@cs.rwth-aachen.de                 en        de
# 11882 5432  guta_guta@cs.rwth-aachen.de                 en        de
# 11883 5432  guta_guta@cs.rwth-aachen.de                 en        de
# 11884 5431  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11885 5431  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11886 5431  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11887 5431  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11888 5431  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11889 5431  maja.popovic_maja.popovic.166@gmail.com     en        de
# 11890 5431  maja.popovic_maja.popovic.166@gmail.com     en        de
# 11891 5431  maja.popovic_maja.popovic.166@gmail.com     en        de
# 11892 5431  maja.popovic_maja.popovic.166@gmail.com     en        de
# 11893 5427  maja.popovic_maja.popovic.166@gmail.com     en        de
# 11894 5427  maja.popovic_maja.popovic.166@gmail.com     en        de
# 11895 5432  guta_guta@cs.rwth-aachen.de                 en        de
# 11896 5427  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11897 5427  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11898 5427  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11899 5427  maja.popovic.166_maja.popovic.166@gmail.com en        de
# 11900 5427  maja.popovic.166_maja.popovic.166@gmail.com en        de
#       Input.item hit  sys_id                   rid type    sid  score
# 1     ad         1759 RWTH-nmt-ensemble.4921   NA  SYSTEM  1467  0.22573164
# 2     ad         1768 uedin-nmt.4722           NA  SYSTEM   586  0.48791593
# 3     ad         1768 PROMT-Rule-based.4735    NA  SYSTEM  1018  0.18072139
# 4     ad         1768 C-3MA.4959               NA  SYSTEM  1540 -1.93124103
# 5     ad         1768 SYSTRAN.4847             NA  SYSTEM  2237 -0.01127519
# 6     ad         1768 online-G.0               NA  SYSTEM  1480 -0.97125811
# 7     ad         1775 LMU-nmt-reranked.4934    NA  SYSTEM   788 -1.12485538
# 8     ad         1775 RWTH-nmt-ensemble.4921   NA  SYSTEM  1913 -1.54724786
# 9     ad         1775 uedin-nmt.4722           NA  SYSTEM  1961  0.91030841
# 10    ad         1782 LIUM-NMT.4900            NA  BAD_REF  759 -1.34074853
# 11    ad         1782 REFERENCE                NA  REF     1322  1.46996820
# 12    ad         1782 KIT.4950                 NA  BAD_REF  439 -0.02433689
# 13    ad         1775 uedin-nmt.4722           NA  SYSTEM  1648 -0.51046631
# 14    ad         1775 uedin-nmt.4722           NA  SYSTEM  2430 -0.97125811
# 15    ad         1775 LMU-nmt-single.4893      NA  SYSTEM   424 -0.28007041
# 16    ad         1775 online-F.0               NA  SYSTEM  2600 -1.00965743
# 17    ad         1775 uedin-nmt.4722           NA  BAD_REF 1961 -0.54886563
# 18    ad         1759 online-A.0               NA  SYSTEM  2040 -0.55991924
# 19    ad         1796 PROMT-Rule-based.4735    NA  BAD_REF 1835 -0.21499040
# 20    ad         1796 xmu.4910                 NA  SYSTEM   741  1.13791096
# 21    ad         1796 online-F.0               NA  SYSTEM   920  1.09563279
# 22    ad         1803 C-3MA.4959               NA  SYSTEM  1845 -1.46106724
# 23    ad         1803 KIT.4950                 NA  BAD_REF 1420  1.10220862
# 24    ad         1803 fbk-nmt-combination.4870 NA  SYSTEM  2464  0.18103136
# 25    ad         1803 xmu.4910                 NA  SYSTEM  1153 -1.22076013
# 26    ad         1803 LMU-nmt-single.4893      NA  SYSTEM  1386 -0.41973642
# 27    ad         1803 REFERENCE                NA  REF     2542  1.62287403
# 28    ad         1803 online-B.0               NA  SYSTEM  2807  0.66164558
# 29    ad         1803 uedin-nmt.4722           NA  SYSTEM   873 -0.41973642
# 30    ad         1803 LIUM-NMT.4900            NA  SYSTEM  1816  0.62159440
# ⋮     ⋮          ⋮    ⋮                        ⋮   ⋮       ⋮    ⋮
# 11871 ad         5430 fbk-nmt-combination.4870 NA  SYSTEM  2400  0.12846156
# 11872 ad         5430 online-F.0               NA  SYSTEM  1611 -0.52776609
# 11873 ad         5431 fbk-nmt-combination.4870 NA  SYSTEM  1973  0.14232208
# 11874 ad         5431 LMU-nmt-single.4893      NA  SYSTEM  1845  1.14070431
# 11875 ad         5431 fbk-nmt-combination.4870 NA  SYSTEM  1973 -1.09024693
# 11876 ad         5431 LMU-nmt-single.4893      NA  SYSTEM  1845  0.90968495
# 11877 ad         5431 online-A.0               NA  SYSTEM   319 -1.08645606
# 11878 ad         5431 PROMT-Rule-based.4735    NA  SYSTEM   794  0.10392276
# 11879 ad         5431 xmu.4910                 NA  REPEAT   716 -0.47999174
# 11880 ad         5431 online-A.0               NA  SYSTEM   319  0.50344879
# 11881 ad         5431 PROMT-Rule-based.4735    NA  SYSTEM   794 -0.30902354
# 11882 ad         5432 C-3MA.4959               NA  SYSTEM  1970  0.94093389
# 11883 ad         5432 C-3MA.4959               NA  SYSTEM  2037 -0.27777460
# 11884 ad         5431 fbk-nmt-combination.4870 NA  SYSTEM  1973 -1.48679594
# 11885 ad         5431 LMU-nmt-single.4893      NA  SYSTEM  1845 -0.08446152
# 11886 ad         5431 online-G.0               NA  BAD_REF  599 -1.52275324
# 11887 ad         5431 online-A.0               NA  SYSTEM   319 -0.12041882
# 11888 ad         5431 PROMT-Rule-based.4735    NA  SYSTEM   794  0.38298328
# 11889 ad         5431 fbk-nmt-combination.4870 NA  SYSTEM  1973 -1.33807929
# 11890 ad         5431 LMU-nmt-single.4893      NA  SYSTEM  1845 -0.55407525
# 11891 ad         5431 online-A.0               NA  SYSTEM   319 -0.34025597
# 11892 ad         5431 PROMT-Rule-based.4735    NA  SYSTEM   794  0.62193080
# 11893 ad         5427 online-B.0               NA  SYSTEM  1557  0.08738260
# 11894 ad         5427 xmu.4910                 NA  SYSTEM  1190  0.12301914
# 11895 ad         5432 online-G.0               NA  SYSTEM   145 -1.05899799
# 11896 ad         5427 online-B.0               NA  SYSTEM  2555  1.17404372
# 11897 ad         5427 SYSTRAN.4847             NA  SYSTEM  1169 -0.69573550
# 11898 ad         5427 KIT.4950                 NA  SYSTEM  1649  0.67064163
# 11899 ad         5427 online-B.0               NA  SYSTEM  1557  0.09532494
# 11900 ad         5427 xmu.4910                 NA  SYSTEM  1190  0.34702599
#       time
# 1      42.1
# 2      26.0
# 3      23.9
# 4      19.1
# 5      12.6
# 6      14.1
# 7      12.9
# 8      16.2
# 9      24.9
# 10     16.9
# 11     17.3
# 12     11.8
# 13     12.2
# 14     54.0
# 15     20.0
# 16     19.6
# 17     18.8
# 18     33.0
# 19     38.6
# 20     26.1
# 21     13.0
# 22     17.1
# 23     14.9
# 24     23.4
# 25      9.8
# 26     20.9
# 27      7.5
# 28     16.2
# 29      8.8
# 30    103.9
# ⋮     ⋮
# 11871  49.2
# 11872 105.6
# 11873  36.3
# 11874  14.0
# 11875  33.7
# 11876  11.4
# 11877  28.9
# 11878  10.0
# 11879  34.3
# 11880  60.3
# 11881  21.6
# 11882  50.9
# 11883   6.3
# 11884 136.9
# 11885   9.6
# 11886  10.8
# 11887  13.3
# 11888  24.3
# 11889 317.6
# 11890 210.9
# 11891  24.5
# 11892  24.8
# 11893  22.6
# 11894  46.2
# 11895  19.4
# 11896  42.7
# 11897  36.9
# 11898  12.9
# 11899  18.7
# 11900  13.4

# %% [markdown]
# - 可以看出针对一个句子，并不是每个MT都有对应的分数，而有一些MT可能拥有多个分数(因为有多个人对这个译文进行评分)

# %%
summary(data)
# Out:
#      HITId                                      WorkerId    Input.src
#  Min.   :1625   mhuck_mhuck@cis.lmu.de              :2028   en:11900
#  1st Qu.:1660   lmu-simon_riess.simon@yahoo.de      :1209
#  Median :1741   chanberg_chantal.amrhein@uzh.ch     :1100
#  Mean   :2532   yvesscherrer_yves.scherrer@gmail.com:1010
#  3rd Qu.:2148   Natalia_Natalia.Zheleznyak@promt.ru :1000
#  Max.   :5434   UE_Caelan_dark1thought@hotmail.co.uk: 740
#                 (Other)                             :4813
#  Input.trg  Input.item      hit                          sys_id
#  de:11900   ad:11900   Min.   :1625   REFERENCE             : 835
#                        1st Qu.:1660   online-G.0            : 807
#                        Median :1741   SYSTRAN.4847          : 754
#                        Mean   :2532   C-3MA.4959            : 748
#                        3rd Qu.:2148   TALP-UPC.4834         : 737
#                        Max.   :5434   RWTH-nmt-ensemble.4921: 732
#                                       (Other)               :7287
#    rid               type           sid           score
#  Mode:logical   BAD_REF: 836   Min.   :   2   Min.   :-4.1737
#  NA's:11900     REF    : 835   1st Qu.: 730   1st Qu.:-0.7679
#                 REPEAT : 837   Median :1457   Median : 0.1294
#                 SYSTEM :9392   Mean   :1479   Mean   : 0.0000
#                                3rd Qu.:2220   3rd Qu.: 0.9096
#                                Max.   :3004   Max.   : 1.9624
#
#       time
#  Min.   :    2.50
#  1st Qu.:   11.70
#  Median :   18.40
#  Mean   :   75.37
#  3rd Qu.:   30.40
#  Max.   :65551.00

# %%
sys_data = subset(data, data$type == "SYSTEM", select = c(sys_id, sid, score))

# %% [markdown]
# - 我们只需要sys_id, sid, score这三列数据，用于提取文件

# %%
library("data.table")
sys_data = data.table(sys_data)
sys_data = sys_data[order(sys_data$sys_id)]
summary(sys_data$sys_id)
# Out:
#               C-3MA.4959 fbk-nmt-combination.4870                 KIT.4950
#                      628                      525                      532
#            LIUM-NMT.4900    LMU-nmt-reranked.4934      LMU-nmt-single.4893
#                      546                      600                      477
#               online-A.0               online-B.0               online-F.0
#                      585                      590                      590
#               online-G.0    PROMT-Rule-based.4735                REFERENCE
#                      687                      610                        0
#   RWTH-nmt-ensemble.4921             SYSTRAN.4847            TALP-UPC.4834
#                      624                      630                      633
#           uedin-nmt.4722                 xmu.4910
#                      509                      626

# %% [markdown]
# 为了方便数据读取，下面把这个文件按其mt系统的类型进行划分，分别存储到不同的文件中。其中的数据按照sid进行排序。这样在读取的时候，就只需要顺序读，读到没有的行就直接跳过就行了。 保存的文件，每一行的数据用逗号分隔开。

# %%
save.file = function(id){
  tmp = subset(sys_data, sys_data$sys_id == id, select = c(sid, score))
  tmp = tmp[order(tmp$sid)]
  write.table(tmp, file = id, row.names = FALSE, col.names = FALSE, sep = ",")
}

# %%
getwd()
setwd("./test_data")
# Out:
# [1] "/Users/ihuangyiran/Documents/Workplace_Python/MasterArbeit"

# %%
sys_id = unique(sys_data$sys_id)
sys_id = as.character(sys_id)

counter = 1
nu = length(sys_id)
while(counter <= nu ){
  save.file(sys_id[counter])
  counter = counter + 1
}

# %%
sys_id
# Out:
#  [1] "C-3MA.4959"               "fbk-nmt-combination.4870"
#  [3] "KIT.4950"                 "LIUM-NMT.4900"
#  [5] "LMU-nmt-reranked.4934"    "LMU-nmt-single.4893"
#  [7] "online-A.0"               "online-B.0"
#  [9] "online-F.0"               "online-G.0"
# [11] "PROMT-Rule-based.4735"    "RWTH-nmt-ensemble.4921"
# [13] "SYSTRAN.4847"             "TALP-UPC.4834"
# [15] "uedin-nmt.4722"           "xmu.4910"
