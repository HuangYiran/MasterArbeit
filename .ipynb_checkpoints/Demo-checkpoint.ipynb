# %% [markdown]
# ### Introduction
# - The task is: evaluate the sentence with the help of a MT model.
# - Training model: train a NN to evaluate the sentence
#     - data set: the system output sentence set, reference sentence set and a record for each sys-ref senetncee pair.
# - Test model:
#     - input a system sentence and a reference sentence output a record which correspond to the similarity of the sentence pair.
# - The idea is:
#     - use the sentence as the input of the decoder in the MT model and get the hidden value for each sentence. we use these hidden value instead of the original sentence to do the evaluation.

# %% [markdown]
# # E1
# only use the hidden value of the last word in the sentence to do the evaluation. Because the decoder of the MT mdoel is RNN. The hidden value of the last word has contained all the information we need.
# #### Training data
# - system output sentences come from the following files:

# %%
filenames = ['newstest2017.C-3MA.4959.en-de', 'newstest2017.fbk-nmt-combination.4870.en-de','newstest2017.KIT.4950.en-de','newstest2017.LIUM-NMT.4900.en-de','newstest2017.LMU-nmt-reranked.4934.en-de','newstest2017.LMU-nmt-single.4893.en-de','newstest2017.online-A.0.en-de','newstest2017.online-B.0.en-de','newstest2017.online-F.0.en-de','newstest2017.online-G.0.en-de','newstest2017.PROMT-Rule-based.4735.en-de','newstest2017.RWTH-nmt-ensemble.4921.en-de','newstest2017.SYSTRAN.4847.en-de','newstest2017.TALP-UPC.4834.en-de','newstest2017.uedin-nmt.4722.en-de','newstest2017.xmu.4910.en-de']
filenames
# Out:
# ['newstest2017.C-3MA.4959.en-de',
#  'newstest2017.fbk-nmt-combination.4870.en-de',
#  'newstest2017.KIT.4950.en-de',
#  'newstest2017.LIUM-NMT.4900.en-de',
#  'newstest2017.LMU-nmt-reranked.4934.en-de',
#  'newstest2017.LMU-nmt-single.4893.en-de',
#  'newstest2017.online-A.0.en-de',
#  'newstest2017.online-B.0.en-de',
#  'newstest2017.online-F.0.en-de',
#  'newstest2017.online-G.0.en-de',
#  'newstest2017.PROMT-Rule-based.4735.en-de',
#  'newstest2017.RWTH-nmt-ensemble.4921.en-de',
#  'newstest2017.SYSTRAN.4847.en-de',
#  'newstest2017.TALP-UPC.4834.en-de',
#  'newstest2017.uedin-nmt.4722.en-de',
#  'newstest2017.xmu.4910.en-de']

# %% [markdown]
# - ref sentences come from the following file:

# %%
filename = "./data/wmt17-metrics-task/wmt17-submitted-data/txt/references/newstest2017-ende-ref.de"
filename
# Out:
# './data/wmt17-metrics-task/wmt17-submitted-data/txt/references/newstest2017-ende-ref.de'

# %% [markdown]
# - we extract the score from the file'ad-ende-good-stnd.csv' in wmt17-metrics-task.
#
# ### Test data
# wmt16-metrics-task doesn't contain en-de task. We use part of the wmt17-metrics-task data as test data

# %% [markdown]
# #### MT model
# - we use the MT model from kit: prepro_model_ppl_20.07_e13.pt

# %% [markdown]
# ### Procedure
# - use the get_hidden method to get the the last hidden value for each sentence
# - use the hidden value and the score to train the model
# - use the hyperopt to choose the parameter

# %% [markdown]
# ### Result

# %%
import fmin
import Params

# %% [markdown]
# #### mlp model
# - train the model below with MSELOSS and Adam

# %%
BasicLinear (
  (layers): Sequential (
    (fc1): Linear (1000 -> 100)
    (bn): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True)
    (LeakyReLU1): LeakyReLU (0.01)
    (fc2): Linear (100 -> 10)
    (bn2): BatchNorm1d(10, eps=1e-05, momentum=0.193385289254, affine=True)
    (LeakyReLU2): LeakyReLU (0.01)
    (fc3): Linear (10 -> 1)
  )
)

# %%
opt = Params.Params()
pas = {'dim2': 10, 'act_func_out': None, 'tgt': '../data/MasterArbeit/data/data_scores', 'src_sys': '../data/MasterArbeit/test/train_sys_hidden', 'src_ref': '../data/MasterArbeit/test/train_ref_hidden', 'val_tgt': '../data/MasterArbeit/test/val_scores', 'src_val_sys': '../data/MasterArbeit/test/val_sys_hidden', 'src_val_ref': '../data/MasterArbeit/test/val_ref_hidden', 'test_tgt': '../data/MasterArbeit/test/test_scores', 'src_test_sys': '../data/MasterArbeit/test/test_sys_hidden', 'src_test_ref': '../data/MasterArbeit/test/test_ref_hidden', 'optim': 'Adam','loss_fn': 'MSELoss', 'batch_size': 100, 'dim2': 100, 'dim3': 10, 'lr': 0.00592636698766986, 'act_func': 'LeakyReLU', 'act_func_out': None, 'model': './model/LinearModel', 'type': 'linear', 'momentum': 0.19338528925355508, 'drop_out_rate': 0.5683040090088415}
opt.set_params(pas)
fmin.o_func(pas)
# Out:
# ('act_func_out', None)
# ('tgt', '../data/MasterArbeit/data/data_scores')
# ('loss_fn', 'MSELoss')
# ('src_test_sys', '../data/MasterArbeit/test/test_sys_hidden')
# ('dim2', 100)
# ('dim3', 10)
# ('val_tgt', '../data/MasterArbeit/test/val_scores')
# ('test_tgt', '../data/MasterArbeit/test/test_scores')
# ('weight_decay', 0)
# ('out', './test_data/pred')
# ('src_test_ref', '../data/MasterArbeit/test/test_ref_hidden')
# ('lr', 0.00592636698766986)
# ('act_func', 'LeakyReLU')
# ('drop_out_rate', 0.5683040090088415)
# ('type', 'linear')
# ('momentum', 0.19338528925355508)
# ('src_val_ref', '../data/MasterArbeit/test/val_ref_hidden')
# ('optim', 'Adam')
# ('batch_size', 100)
# ('src_val_sys', '../data/MasterArbeit/test/val_sys_hidden')
# ('src_sys', '../data/MasterArbeit/test/train_sys_hidden')
# ('src_ref', '../data/MasterArbeit/test/train_ref_hidden')
# ('eps', 1e-08)
# ('model', './model/LinearModel')
# BasicLinear (
#   (layers): Sequential (
#     (fc1): Linear (1000 -> 100)
#     (bn): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True)
#     (LeakyReLU1): LeakyReLU (0.01)
#     (fc2): Linear (100 -> 10)
#     (bn2): BatchNorm1d(10, eps=1e-05, momentum=0.193385289254, affine=True)
#     (LeakyReLU2): LeakyReLU (0.01)
#     (fc3): Linear (10 -> 1)
#   )
# )
# number of batch is 75
# number of val batch 9
# number of test batch 9
# evaluate 0
# the correlation coeffizient is : 0.039752
# the mean loss is 1.067239
# evaluate 1
# the correlation coeffizient is : 0.106255
# the mean loss is 0.889404
# evaluate 2
# the correlation coeffizient is : 0.358786
# the mean loss is 0.879562
# evaluate 3
# the correlation coeffizient is : 0.226682
# the mean loss is 0.882280
# evaluate 4
# the correlation coeffizient is : 0.343769
# the mean loss is 0.838042
# evaluate 5
# the correlation coeffizient is : 0.340741
# the mean loss is 1.067171
# evaluate 6
# the correlation coeffizient is : 0.351553
# the mean loss is 0.966498
# evaluate 7
# the correlation coeffizient is : 0.371904
# the mean loss is 0.673544
# evaluate 8
# the correlation coeffizient is : 0.254012
# the mean loss is 0.888340
# evaluate 9
# the correlation coeffizient is : 0.302974
# the mean loss is 0.942413
# evaluate 10
# the correlation coeffizient is : 0.369812
# the mean loss is 0.795755
# evaluate 11
# the correlation coeffizient is : 0.394643
# the mean loss is 0.819760
# evaluate 12
# the correlation coeffizient is : 0.239039
# the mean loss is 0.896118
# evaluate 13
# the correlation coeffizient is : 0.422415
# the mean loss is 0.778399
# evaluate 14
# the correlation coeffizient is : 0.420214
# the mean loss is 0.991666
# evaluate 15
# the correlation coeffizient is : 0.491067
# the mean loss is 0.827426
# evaluate 16
# the correlation coeffizient is : 0.313392
# the mean loss is 0.710824
# evaluate 17
# the correlation coeffizient is : 0.392367
# the mean loss is 0.818652
# evaluate 18
# the correlation coeffizient is : 0.376329
# the mean loss is 0.924076
# evaluate 19
# the correlation coeffizient is : 0.442979
# the mean loss is 0.747990
# evaluate 20
# the correlation coeffizient is : 0.451551
# the mean loss is 0.770607
# evaluate 21
# the correlation coeffizient is : 0.288482
# the mean loss is 0.870422
# evaluate 22
# the correlation coeffizient is : 0.526308
# the mean loss is 0.685511
# evaluate 23
# the correlation coeffizient is : 0.413966
# the mean loss is 0.988619
# evaluate 24
# the correlation coeffizient is : 0.524356
# the mean loss is 0.790219
# evaluate 25
# the correlation coeffizient is : 0.289108
# the mean loss is 0.780840
# evaluate 26
# the correlation coeffizient is : 0.444836
# the mean loss is 0.805447
# evaluate 27
# the correlation coeffizient is : 0.314252
# the mean loss is 1.015733
# evaluate 28
# the correlation coeffizient is : 0.430090
# the mean loss is 0.774837
# evaluate 29
# the correlation coeffizient is : 0.448420
# the mean loss is 0.776018
# evaluate 30
# the correlation coeffizient is : 0.307657
# the mean loss is 0.889449
# evaluate 31
# the correlation coeffizient is : 0.526299
# the mean loss is 0.676598
# evaluate 32
# the correlation coeffizient is : 0.429558
# the mean loss is 0.975690
# evaluate 33
# the correlation coeffizient is : 0.517227
# the mean loss is 0.796858
# evaluate 34
# the correlation coeffizient is : 0.230681
# the mean loss is 0.942654
# evaluate 35
# the correlation coeffizient is : 0.432551
# the mean loss is 0.841635
# evaluate 36
# the correlation coeffizient is : 0.339242
# the mean loss is 0.974800
# evaluate 37
# the correlation coeffizient is : 0.392379
# the mean loss is 0.826535
# evaluate 38
# the correlation coeffizient is : 0.425301
# the mean loss is 0.808409
# evaluate 39
# the correlation coeffizient is : 0.340718
# the mean loss is 0.884194
# evaluate 40
# the correlation coeffizient is : 0.553167
# the mean loss is 0.656222
# evaluate 41
# the correlation coeffizient is : 0.381121
# the mean loss is 1.045991
# evaluate 42
# the correlation coeffizient is : 0.528943
# the mean loss is 0.771378
# evaluate 43
# the correlation coeffizient is : 0.252655
# the mean loss is 0.959068
# evaluate 44
# the correlation coeffizient is : 0.494412
# the mean loss is 0.769404
# evaluate 45
# the correlation coeffizient is : 0.362578
# the mean loss is 0.972521
# evaluate 46
# the correlation coeffizient is : 0.303459
# the mean loss is 0.908265
# evaluate 47
# the correlation coeffizient is : 0.370541
# the mean loss is 0.876414
# evaluate 48
# the correlation coeffizient is : 0.346616
# the mean loss is 0.914542
# evaluate 49
# the correlation coeffizient is : 0.534021
# the mean loss is 0.681933
# evaluate 50
# the correlation coeffizient is : 0.411158
# the mean loss is 1.010636
# evaluate 51
# the correlation coeffizient is : 0.537666
# the mean loss is 0.776986
# evaluate 52
# the correlation coeffizient is : 0.319618
# the mean loss is 0.889245
# evaluate 53
# the correlation coeffizient is : 0.489873
# the mean loss is 0.782263
# evaluate 54
# the correlation coeffizient is : 0.374875
# the mean loss is 0.956482
# evaluate 55
# the correlation coeffizient is : 0.355655
# the mean loss is 0.843503
# evaluate 56
# the correlation coeffizient is : 0.373639
# the mean loss is 0.880987
# evaluate 57
# the correlation coeffizient is : 0.362520
# the mean loss is 0.902953
# evaluate 58
# the correlation coeffizient is : 0.497653
# the mean loss is 0.731828
# evaluate 59
# the correlation coeffizient is : 0.424385
# the mean loss is 1.006409
# evaluate 60
# the correlation coeffizient is : 0.545839
# the mean loss is 0.773912
# evaluate 61
# the correlation coeffizient is : 0.308899
# the mean loss is 0.877101
# evaluate 62
# the correlation coeffizient is : 0.500806
# the mean loss is 0.754105
# evaluate 63
# the correlation coeffizient is : 0.379713
# the mean loss is 0.927889
# evaluate 64
# the correlation coeffizient is : 0.353345
# the mean loss is 0.890539
# evaluate 65
# the correlation coeffizient is : 0.374099
# the mean loss is 0.879961
# evaluate 66
# the correlation coeffizient is : 0.316658
# the mean loss is 0.977125
# evaluate 67
# the correlation coeffizient is : 0.461205
# the mean loss is 0.817414
# evaluate 68
# the correlation coeffizient is : 0.441584
# the mean loss is 1.021527
# evaluate 69
# the correlation coeffizient is : 0.521617
# the mean loss is 0.805033
# evaluate 70
# the correlation coeffizient is : 0.354070
# the mean loss is 0.816073
# evaluate 71
# the correlation coeffizient is : 0.516974
# the mean loss is 0.728359
# evaluate 72
# the correlation coeffizient is : 0.362116
# the mean loss is 0.965115
# evaluate 73
# the correlation coeffizient is : 0.347602
# the mean loss is 0.917739
# evaluate 74
# the correlation coeffizient is : 0.409088
# the mean loss is 0.836408
# evaluate 75
# the correlation coeffizient is : 0.340516
# the mean loss is 0.972086
# evaluate 76
# the correlation coeffizient is : 0.455833
# the mean loss is 0.848290
# evaluate 77
# the correlation coeffizient is : 0.457411
# the mean loss is 1.000529
# evaluate 78
# the correlation coeffizient is : 0.505447
# the mean loss is 0.855306
# evaluate 79
# the correlation coeffizient is : 0.358826
# the mean loss is 0.803680
# evaluate 80
# the correlation coeffizient is : 0.519273
# the mean loss is 0.717472
# evaluate 81
# the correlation coeffizient is : 0.361830
# the mean loss is 0.996480
# evaluate 82
# the correlation coeffizient is : 0.307799
# the mean loss is 0.948006
# evaluate 83
# the correlation coeffizient is : 0.445891
# the mean loss is 0.812058
# evaluate 84
# the correlation coeffizient is : 0.359194
# the mean loss is 1.001154
# evaluate 85
# the correlation coeffizient is : 0.453616
# the mean loss is 0.873409
# evaluate 86
# the correlation coeffizient is : 0.491667
# the mean loss is 0.939543
# evaluate 87
# the correlation coeffizient is : 0.521094
# the mean loss is 0.826328
# evaluate 88
# the correlation coeffizient is : 0.352462
# the mean loss is 0.782908
# evaluate 89
# the correlation coeffizient is : 0.496498
# the mean loss is 0.761361
# evaluate 90
# the correlation coeffizient is : 0.400537
# the mean loss is 0.955366
# evaluate 91
# the correlation coeffizient is : 0.349166
# the mean loss is 0.910676
# evaluate 92
# the correlation coeffizient is : 0.464204
# the mean loss is 0.806692
# evaluate 93
# the correlation coeffizient is : 0.371749
# the mean loss is 0.994134
# evaluate 94
# the correlation coeffizient is : 0.477688
# the mean loss is 0.834249
# evaluate 95
# the correlation coeffizient is : 0.516904
# the mean loss is 0.929100
# evaluate 96
# the correlation coeffizient is : 0.535133
# the mean loss is 0.801905
# evaluate 97
# the correlation coeffizient is : 0.292370
# the mean loss is 0.840852
# evaluate 98
# the correlation coeffizient is : 0.448560
# the mean loss is 0.848378
# evaluate 99
# the correlation coeffizient is : 0.412686
# the mean loss is 0.920418
# evaluate 100
# the correlation coeffizient is : 0.343640
# the mean loss is 0.925132
# evaluate 101
# the correlation coeffizient is : 0.502046
# the mean loss is 0.771494
# evaluate 102
# the correlation coeffizient is : 0.389031
# the mean loss is 1.000997
# evaluate 103
# the correlation coeffizient is : 0.474676
# the mean loss is 0.819482
# evaluate 104
# the correlation coeffizient is : 0.509942
# the mean loss is 0.946946
# evaluate 105
# the correlation coeffizient is : 0.507655
# the mean loss is 0.828675
# evaluate 106
# the correlation coeffizient is : 0.300959
# the mean loss is 0.873220
# evaluate 107
# the correlation coeffizient is : 0.449587
# the mean loss is 0.830527
# evaluate 108
# the correlation coeffizient is : 0.436261
# the mean loss is 0.896782
# evaluate 109
# the correlation coeffizient is : 0.373168
# the mean loss is 0.925537
# evaluate 110
# the correlation coeffizient is : 0.514910
# the mean loss is 0.761155
# evaluate 111
# the correlation coeffizient is : 0.363184
# the mean loss is 1.028497
# evaluate 112
# the correlation coeffizient is : 0.506848
# the mean loss is 0.780493
# the correlation coeffizient is : 0.449817
# the correlation coeffizient is : 0.408235
# the correlation coeffizient is : 0.394523
# the correlation coeffizient is : 0.442708
# the correlation coeffizient is : 0.548897
# the correlation coeffizient is : 0.398084
# the correlation coeffizient is : 0.334725
# the correlation coeffizient is : 0.411484
# the correlation coeffizient is : 0.385968
# the correlation coeffizient is : 0.449817
# 0.57757420250889102

# %% [markdown]
# - plot the result
#
# The result is bad, the maximal corr is 0.5 with a large var. and the loss value is not reduced.

# %%
install.packages('ggplot2')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(ggplot2)
loss = read.table('../data/MasterArbeit/mid_result/loss', header = FALSE, sep = ',')
corr = read.table('../data/MasterArbeit/mid_result/corr', header = FALSE, sep = ',')

# %%
p_corr = ggplot(corr, aes(x = V1, y = V2))
p_corr + geom_point() + xlab("number of batch") + ylab("corr") + ylim(0.0, 1.0)
# Out:
# plot without title

# %%
p_loss = ggplot(loss, aes(x = V1, y = V2))
p_loss + geom_point() + xlab("number of batch") + ylab("loss") + ylim(0, max(loss$V2, 2))
# Out:
# plot without title

# %%
idea: benutze dropout statt BatchNorm, BN braucht extra zwei Parameters für jeden Unit. 
BasicLinear_dropout (
  (layers): Sequential (
    (fc1): Linear (1000 -> 100)
    (LeakyReLU1): LeakyReLU (0.01)
    (fc2): Linear (100 -> 10)
    (LeakyReLU2): LeakyReLU (0.01)
    (drop_out): Dropout (p = 0.568304009009)
    (fc3): Linear (10 -> 1)
  )
)

# %%
opt = Params.Params()
pas = {'tgt': '../data/MasterArbeit/data/data_scores', 'src_sys': '../data/MasterArbeit/test/train_sys_hidden', 'src_ref': '../data/MasterArbeit/test/train_ref_hidden', 'val_tgt': '../data/MasterArbeit/test/val_scores', 'src_val_sys': '../data/MasterArbeit/test/val_sys_hidden', 'src_val_ref': '../data/MasterArbeit/test/val_ref_hidden', 'test_tgt': '../data/MasterArbeit/test/test_scores', 'src_test_sys': '../data/MasterArbeit/test/test_sys_hidden', 'src_test_ref': '../data/MasterArbeit/test/test_ref_hidden', 'batch_size': 100, 'dim2': 100, 'dim3': 10, 'lr': 0.01592636698766986, 'act_func': 'LeakyReLU', 'act_func_out': None, 'model': 'BasicLinearDropout', 'type': 'linear', 'momentum': 0.19338528925355508, 'drop_out_rate': 0.5683040090088415}
opt.set_params(pas)
fmin.o_func(pas)
# Out:
# ('act_func_out', None)
# ('tgt', '../data/MasterArbeit/data/data_scores')
# ('loss_fn', 'MSELoss')
# ('src_test_sys', '../data/MasterArbeit/test/test_sys_hidden')
# ('dim2', 100)
# ('dim3', 10)
# ('val_tgt', '../data/MasterArbeit/test/val_scores')
# ('test_tgt', '../data/MasterArbeit/test/test_scores')
# ('weight_decay', 0)
# ('out', './test_data/pred')
# ('src_test_ref', '../data/MasterArbeit/test/test_ref_hidden')
# ('lr', 0.01592636698766986)
# ('act_func', 'LeakyReLU')
# ('drop_out_rate', 0.5683040090088415)
# ('type', 'linear')
# ('momentum', 0.19338528925355508)
# ('src_val_ref', '../data/MasterArbeit/test/val_ref_hidden')
# ('optim', 'Adam')
# ('batch_size', 100)
# ('src_val_sys', '../data/MasterArbeit/test/val_sys_hidden')
# ('src_sys', '../data/MasterArbeit/test/train_sys_hidden')
# ('src_ref', '../data/MasterArbeit/test/train_ref_hidden')
# ('eps', 1e-08)
# ('model', 'BasicLinearDropout')
# BasicLinear_dropout (
#   (layers): Sequential (
#     (fc1): Linear (1000 -> 100)
#     (LeakyReLU1): LeakyReLU (0.01)
#     (fc2): Linear (100 -> 10)
#     (LeakyReLU2): LeakyReLU (0.01)
#     (drop_out): Dropout (p = 0.568304009009)
#     (fc3): Linear (10 -> 1)
#   )
# )
# number of batch is 75
# number of val batch 9
# number of test batch 9
# evaluate 0
# the correlation coeffizient is : 0.118016
# the mean loss is 0.994761
# evaluate 1
# the correlation coeffizient is : -0.124693
# the mean loss is 0.899095
# evaluate 2
# the correlation coeffizient is : 0.089783
# the mean loss is 0.985196
# evaluate 3
# the correlation coeffizient is : -0.064687
# the mean loss is 0.911916
# evaluate 4
# the correlation coeffizient is : 0.152360
# the mean loss is 0.962425
# evaluate 5
# the correlation coeffizient is : -0.009258
# the mean loss is 1.191391
# evaluate 6
# the correlation coeffizient is : 0.158150
# the mean loss is 1.090703
# evaluate 7
# the correlation coeffizient is : -0.244036
# the mean loss is 0.760192
# evaluate 8
# the correlation coeffizient is : -0.017746
# the mean loss is 0.960770
# evaluate 9
# the correlation coeffizient is : -0.106076
# the mean loss is 1.035038
# evaluate 10
# the correlation coeffizient is : 0.066655
# the mean loss is 0.904888
# evaluate 11
# the correlation coeffizient is : -0.138184
# the mean loss is 0.962214
# evaluate 12
# the correlation coeffizient is : 0.080562
# the mean loss is 0.917630
# evaluate 13
# the correlation coeffizient is : 0.064841
# the mean loss is 0.934385
# evaluate 14
# the correlation coeffizient is : -0.028028
# the mean loss is 1.184915
# evaluate 15
# the correlation coeffizient is : 0.139872
# the mean loss is 1.071595
# evaluate 16
# the correlation coeffizient is : 0.014168
# the mean loss is 0.776612
# evaluate 17
# the correlation coeffizient is : 0.199830
# the mean loss is 0.960862
# evaluate 18
# the correlation coeffizient is : 0.156263
# the mean loss is 0.993360
# evaluate 19
# the correlation coeffizient is : 0.066923
# the mean loss is 0.910479
# evaluate 20
# the correlation coeffizient is : -0.070405
# the mean loss is 0.978656
# evaluate 21
# the correlation coeffizient is : 0.214248
# the mean loss is 0.936342
# evaluate 22
# the correlation coeffizient is : 0.164991
# the mean loss is 0.944196
# evaluate 23
# the correlation coeffizient is : 0.298586
# the mean loss is 1.193022
# evaluate 24
# the correlation coeffizient is : 0.000906
# the mean loss is 1.096758
# evaluate 25
# the correlation coeffizient is : -0.052670
# the mean loss is 0.792698
# evaluate 26
# the correlation coeffizient is : 0.018637
# the mean loss is 0.962918
# evaluate 27
# the correlation coeffizient is : -0.033669
# the mean loss is 1.060058
# evaluate 28
# the correlation coeffizient is : 0.025932
# the mean loss is 0.876347
# evaluate 29
# the correlation coeffizient is : -0.047680
# the mean loss is 0.943272
# evaluate 30
# the correlation coeffizient is : -0.144162
# the mean loss is 0.916731
# evaluate 31
# the correlation coeffizient is : 0.200533
# the mean loss is 0.921679
# evaluate 32
# the correlation coeffizient is : -0.008978
# the mean loss is 1.174493
# evaluate 33
# the correlation coeffizient is : 0.064453
# the mean loss is 1.068436
# evaluate 34
# the correlation coeffizient is : 0.111742
# the mean loss is 0.972884
# evaluate 35
# the correlation coeffizient is : -0.018797
# the mean loss is 0.968144
# evaluate 36
# the correlation coeffizient is : -0.078934
# the mean loss is 1.018349
# evaluate 37
# the correlation coeffizient is : -0.042829
# the mean loss is 0.873494
# evaluate 38
# the correlation coeffizient is : 0.156926
# the mean loss is 0.956637
# evaluate 39
# the correlation coeffizient is : 0.207937
# the mean loss is 0.912311
# evaluate 40
# the correlation coeffizient is : -0.012383
# the mean loss is 0.930977
# evaluate 41
# the correlation coeffizient is : 0.143539
# the mean loss is 1.208676
# evaluate 42
# the correlation coeffizient is : 0.094359
# the mean loss is 1.095715
# evaluate 43
# the correlation coeffizient is : 0.076339
# the mean loss is 0.812124
# evaluate 44
# the correlation coeffizient is : -0.115343
# the mean loss is 0.961189
# evaluate 45
# the correlation coeffizient is : 0.022229
# the mean loss is 1.012046
# evaluate 46
# the correlation coeffizient is : 0.026748
# the mean loss is 0.882112
# evaluate 47
# the correlation coeffizient is : -0.012565
# the mean loss is 0.925663
# evaluate 48
# the correlation coeffizient is : 0.003761
# the mean loss is 0.913823
# evaluate 49
# the correlation coeffizient is : 0.247166
# the mean loss is 0.923426
# evaluate 50
# the correlation coeffizient is : 0.109557
# the mean loss is 1.170443
# evaluate 51
# the correlation coeffizient is : 0.145632
# the mean loss is 1.094501
# evaluate 52
# the correlation coeffizient is : 0.015895
# the mean loss is 0.780542
# evaluate 53
# the correlation coeffizient is : 0.143701
# the mean loss is 0.944796
# evaluate 54
# the correlation coeffizient is : 0.224702
# the mean loss is 1.029890
# evaluate 55
# the correlation coeffizient is : 0.179116
# the mean loss is 0.904777
# evaluate 56
# the correlation coeffizient is : 0.157813
# the mean loss is 0.949751
# evaluate 57
# the correlation coeffizient is : 0.158613
# the mean loss is 0.898137
# evaluate 58
# the correlation coeffizient is : -0.047314
# the mean loss is 0.950503
# evaluate 59
# the correlation coeffizient is : -0.088387
# the mean loss is 1.165712
# evaluate 60
# the correlation coeffizient is : 0.145259
# the mean loss is 1.084545
# evaluate 61
# the correlation coeffizient is : -0.032123
# the mean loss is 0.763940
# evaluate 62
# the correlation coeffizient is : 0.060179
# the mean loss is 0.951283
# evaluate 63
# the correlation coeffizient is : 0.036099
# the mean loss is 1.021872
# evaluate 64
# the correlation coeffizient is : 0.168963
# the mean loss is 0.874377
# evaluate 65
# the correlation coeffizient is : -0.129208
# the mean loss is 0.966357
# evaluate 66
# the correlation coeffizient is : 0.035390
# the mean loss is 0.934778
# evaluate 67
# the correlation coeffizient is : 0.054528
# the mean loss is 0.994659
# evaluate 68
# the correlation coeffizient is : 0.184130
# the mean loss is 1.184192
# evaluate 69
# the correlation coeffizient is : 0.135775
# the mean loss is 1.113181
# evaluate 70
# the correlation coeffizient is : 0.044806
# the mean loss is 0.753948
# evaluate 71
# the correlation coeffizient is : -0.080707
# the mean loss is 0.946277
# evaluate 72
# the correlation coeffizient is : -0.021697
# the mean loss is 0.981784
# evaluate 73
# the correlation coeffizient is : 0.074513
# the mean loss is 0.921954
# evaluate 74
# the correlation coeffizient is : 0.156896
# the mean loss is 0.931707
# evaluate 75
# the correlation coeffizient is : 0.180465
# the mean loss is 0.905169
# evaluate 76
# the correlation coeffizient is : -0.006173
# the mean loss is 0.942724
# evaluate 77
# the correlation coeffizient is : 0.069716
# the mean loss is 1.179034
# evaluate 78
# the correlation coeffizient is : 0.229212
# the mean loss is 1.065779
# evaluate 79
# the correlation coeffizient is : 0.139388
# the mean loss is 0.784853
# evaluate 80
# the correlation coeffizient is : 0.003677
# the mean loss is 0.947339
# evaluate 81
# the correlation coeffizient is : 0.131148
# the mean loss is 1.014275
# evaluate 82
# the correlation coeffizient is : 0.103665
# the mean loss is 0.862456
# evaluate 83
# the correlation coeffizient is : 0.103850
# the mean loss is 0.968175
# evaluate 84
# the correlation coeffizient is : 0.155985
# the mean loss is 0.930003
# evaluate 85
# the correlation coeffizient is : 0.163299
# the mean loss is 0.904209
# evaluate 86
# the correlation coeffizient is : 0.107975
# the mean loss is 1.198186
# evaluate 87
# the correlation coeffizient is : 0.290219
# the mean loss is 1.058426
# evaluate 88
# the correlation coeffizient is : 0.007965
# the mean loss is 0.751971
# evaluate 89
# the correlation coeffizient is : 0.105260
# the mean loss is 0.945337
# evaluate 90
# the correlation coeffizient is : 0.108761
# the mean loss is 0.995884
# evaluate 91
# the correlation coeffizient is : 0.212886
# the mean loss is 0.909393
# evaluate 92
# the correlation coeffizient is : 0.297159
# the mean loss is 0.976765
# evaluate 93
# the correlation coeffizient is : 0.225313
# the mean loss is 0.924388
# evaluate 94
# the correlation coeffizient is : 0.137459
# the mean loss is 0.871829
# evaluate 95
# the correlation coeffizient is : 0.129197
# the mean loss is 1.175973
# evaluate 96
# the correlation coeffizient is : 0.284530
# the mean loss is 1.063949
# evaluate 97
# the correlation coeffizient is : 0.062981
# the mean loss is 0.757138
# evaluate 98
# the correlation coeffizient is : 0.270343
# the mean loss is 0.929729
# evaluate 99
# the correlation coeffizient is : 0.002877
# the mean loss is 0.976062
# evaluate 100
# the correlation coeffizient is : 0.222899
# the mean loss is 0.897424
# evaluate 101
# the correlation coeffizient is : 0.279537
# the mean loss is 0.957038
# evaluate 102
# the correlation coeffizient is : 0.138545
# the mean loss is 0.870837
# evaluate 103
# the correlation coeffizient is : 0.350668
# the mean loss is 0.875933
# evaluate 104
# the correlation coeffizient is : 0.236664
# the mean loss is 1.146677
# evaluate 105
# the correlation coeffizient is : 0.243756
# the mean loss is 1.023408
# evaluate 106
# the correlation coeffizient is : 0.148332
# the mean loss is 0.719608
# evaluate 107
# the correlation coeffizient is : 0.225089
# the mean loss is 0.936179
# evaluate 108
# the correlation coeffizient is : 0.160241
# the mean loss is 1.028905
# evaluate 109
# the correlation coeffizient is : -0.061493
# the mean loss is 0.916998
# evaluate 110
# the correlation coeffizient is : 0.198347
# the mean loss is 0.922585
# evaluate 111
# the correlation coeffizient is : 0.193792
# the mean loss is 0.850509
# evaluate 112
# the correlation coeffizient is : 0.186787
# the mean loss is 0.890055
# the correlation coeffizient is : 0.050549
# the correlation coeffizient is : 0.217744
# the correlation coeffizient is : 0.315741
# the correlation coeffizient is : 0.416006
# the correlation coeffizient is : 0.186956
# the correlation coeffizient is : 0.082591
# the correlation coeffizient is : 0.356157
# the correlation coeffizient is : 0.099112
# the correlation coeffizient is : 0.067273
# the correlation coeffizient is : 0.108544
# 0.809932582211496

# %% [markdown]
# ### other models

# %%
idea: Anzahle der Parameters reduzieren
BiLinear (
  (li_sys): Linear (500 -> 500)
  (li_ref): Linear (500 -> 500)
  (act_func): LeakyReLU (0.01)
  (fc): Linear (500 -> 10)
  (drop_out): Dropout (p = 0.5)
  (li_out): Linear (10 -> 1)
)

# %%
opt = Params.Params()
pas = {'dim2': 10, 'act_func_out': None, 'tgt': '../data/MasterArbeit/data/data_scores', 'src_sys': '../data/MasterArbeit/test/train_sys_hidden', 'src_ref': '../data/MasterArbeit/test/train_ref_hidden', 'val_tgt': '../data/MasterArbeit/test/val_scores', 'src_val_sys': '../data/MasterArbeit/test/val_sys_hidden', 'src_val_ref': '../data/MasterArbeit/test/val_ref_hidden', 'test_tgt': '../data/MasterArbeit/test/test_scores', 'src_test_sys': '../data/MasterArbeit/test/test_sys_hidden', 'src_test_ref': '../data/MasterArbeit/test/test_ref_hidden', 'batch_size': 100, 'lr': 0.01592636698766986, 'act_func': 'LeakyReLU', 'act_func_out': None , 'model': 'BiLinear'}
opt.set_params(pas)
fmin.o_func(pas)
# Out:
# ('act_func_out', None)
# ('tgt', '../data/MasterArbeit/data/data_scores')
# ('loss_fn', 'MSELoss')
# ('src_test_sys', '../data/MasterArbeit/test/test_sys_hidden')
# ('dim2', 10)
# ('dim3', None)
# ('val_tgt', '../data/MasterArbeit/test/val_scores')
# ('test_tgt', '../data/MasterArbeit/test/test_scores')
# ('weight_decay', 0)
# ('out', './test_data/pred')
# ('src_test_ref', '../data/MasterArbeit/test/test_ref_hidden')
# ('lr', 0.01592636698766986)
# ('act_func', 'LeakyReLU')
# ('drop_out_rate', 0.5)
# ('momentum', 0.1)
# ('src_val_ref', '../data/MasterArbeit/test/val_ref_hidden')
# ('optim', 'Adam')
# ('batch_size', 100)
# ('src_val_sys', '../data/MasterArbeit/test/val_sys_hidden')
# ('src_sys', '../data/MasterArbeit/test/train_sys_hidden')
# ('src_ref', '../data/MasterArbeit/test/train_ref_hidden')
# ('eps', 1e-08)
# ('model', 'BiLinear')
# BiLinear (
#   (li_sys): Linear (500 -> 500)
#   (li_ref): Linear (500 -> 500)
#   (act_func): LeakyReLU (0.01)
#   (fc): Linear (500 -> 10)
#   (drop_out): Dropout (p = 0.5)
#   (li_out): Linear (10 -> 1)
# )
# number of batch is 75
# number of val batch 9
# number of test batch 9
# evaluate 0
# the correlation coeffizient is : 0.146070
# the mean loss is 0.988021
# evaluate 1
# the correlation coeffizient is : 0.081137
# the mean loss is 1.687487
# evaluate 2
# the correlation coeffizient is : 0.007961
# the mean loss is 1.010419
# evaluate 3
# the correlation coeffizient is : 0.027264
# the mean loss is 0.944226
# evaluate 4
# the correlation coeffizient is : 0.138915
# the mean loss is 1.006786
# evaluate 5
# the correlation coeffizient is : 0.050377
# the mean loss is 1.189336
# evaluate 6
# the correlation coeffizient is : 0.188633
# the mean loss is 1.019847
# evaluate 7
# the correlation coeffizient is : 0.032229
# the mean loss is 0.768911
# evaluate 8
# the correlation coeffizient is : 0.080471
# the mean loss is 1.025961
# evaluate 9
# the correlation coeffizient is : 0.212152
# the mean loss is 0.961779
# evaluate 10
# the correlation coeffizient is : 0.173734
# the mean loss is 0.846778
# evaluate 11
# the correlation coeffizient is : 0.292181
# the mean loss is 0.917330
# evaluate 12
# the correlation coeffizient is : 0.126389
# the mean loss is 0.956352
# evaluate 13
# the correlation coeffizient is : 0.178319
# the mean loss is 0.939194
# evaluate 14
# the correlation coeffizient is : 0.058965
# the mean loss is 1.116322
# evaluate 15
# the correlation coeffizient is : 0.190065
# the mean loss is 1.077525
# evaluate 16
# the correlation coeffizient is : 0.242187
# the mean loss is 0.715482
# evaluate 17
# the correlation coeffizient is : 0.222742
# the mean loss is 0.922794
# evaluate 18
# the correlation coeffizient is : 0.207688
# the mean loss is 0.979292
# evaluate 19
# the correlation coeffizient is : 0.324783
# the mean loss is 0.825169
# evaluate 20
# the correlation coeffizient is : 0.274148
# the mean loss is 0.947971
# evaluate 21
# the correlation coeffizient is : 0.178301
# the mean loss is 0.882473
# evaluate 22
# the correlation coeffizient is : 0.296161
# the mean loss is 0.834336
# evaluate 23
# the correlation coeffizient is : 0.319139
# the mean loss is 1.115713
# evaluate 24
# the correlation coeffizient is : 0.316480
# the mean loss is 1.049860
# evaluate 25
# the correlation coeffizient is : 0.128849
# the mean loss is 0.819395
# evaluate 26
# the correlation coeffizient is : 0.245046
# the mean loss is 0.950030
# evaluate 27
# the correlation coeffizient is : 0.115881
# the mean loss is 0.961333
# evaluate 28
# the correlation coeffizient is : 0.383828
# the mean loss is 0.749568
# evaluate 29
# the correlation coeffizient is : 0.329599
# the mean loss is 0.911741
# evaluate 30
# the correlation coeffizient is : 0.107104
# the mean loss is 0.924172
# evaluate 31
# the correlation coeffizient is : 0.311943
# the mean loss is 0.887364
# evaluate 32
# the correlation coeffizient is : 0.275201
# the mean loss is 1.145184
# evaluate 33
# the correlation coeffizient is : 0.245217
# the mean loss is 0.927306
# evaluate 34
# the correlation coeffizient is : 0.169882
# the mean loss is 0.891115
# evaluate 35
# the correlation coeffizient is : 0.276698
# the mean loss is 0.914633
# evaluate 36
# the correlation coeffizient is : 0.187062
# the mean loss is 0.952160
# evaluate 37
# the correlation coeffizient is : 0.346326
# the mean loss is 0.836286
# evaluate 38
# the correlation coeffizient is : 0.476587
# the mean loss is 0.904592
# evaluate 39
# the correlation coeffizient is : 0.192896
# the mean loss is 0.882002
# evaluate 40
# the correlation coeffizient is : 0.337190
# the mean loss is 0.786951
# evaluate 41
# the correlation coeffizient is : 0.352802
# the mean loss is 1.045135
# evaluate 42
# the correlation coeffizient is : 0.340970
# the mean loss is 0.947256
# evaluate 43
# the correlation coeffizient is : 0.289948
# the mean loss is 0.761401
# evaluate 44
# the correlation coeffizient is : 0.210540
# the mean loss is 0.892478
# evaluate 45
# the correlation coeffizient is : 0.238749
# the mean loss is 1.025913
# evaluate 46
# the correlation coeffizient is : 0.361209
# the mean loss is 0.802000
# evaluate 47
# the correlation coeffizient is : 0.389439
# the mean loss is 0.905401
# evaluate 48
# the correlation coeffizient is : 0.156866
# the mean loss is 0.927241
# evaluate 49
# the correlation coeffizient is : 0.405622
# the mean loss is 0.784885
# evaluate 50
# the correlation coeffizient is : 0.297929
# the mean loss is 1.124774
# evaluate 51
# the correlation coeffizient is : 0.260138
# the mean loss is 0.986957
# evaluate 52
# the correlation coeffizient is : 0.298030
# the mean loss is 0.749659
# evaluate 53
# the correlation coeffizient is : 0.372214
# the mean loss is 0.812797
# evaluate 54
# the correlation coeffizient is : 0.396681
# the mean loss is 0.939126
# evaluate 55
# the correlation coeffizient is : 0.341817
# the mean loss is 0.829377
# evaluate 56
# the correlation coeffizient is : 0.411199
# the mean loss is 0.811991
# evaluate 57
# the correlation coeffizient is : 0.305356
# the mean loss is 0.898905
# evaluate 58
# the correlation coeffizient is : 0.378762
# the mean loss is 0.900446
# evaluate 59
# the correlation coeffizient is : 0.323746
# the mean loss is 0.987777
# evaluate 60
# the correlation coeffizient is : 0.340749
# the mean loss is 1.018313
# evaluate 61
# the correlation coeffizient is : 0.290141
# the mean loss is 0.737405
# evaluate 62
# the correlation coeffizient is : 0.398130
# the mean loss is 0.819887
# evaluate 63
# the correlation coeffizient is : 0.323862
# the mean loss is 0.870127
# evaluate 64
# the correlation coeffizient is : 0.368951
# the mean loss is 0.794817
# evaluate 65
# the correlation coeffizient is : 0.399729
# the mean loss is 0.855291
# evaluate 66
# the correlation coeffizient is : 0.329802
# the mean loss is 0.865671
# evaluate 67
# the correlation coeffizient is : 0.432077
# the mean loss is 0.726982
# evaluate 68
# the correlation coeffizient is : 0.372528
# the mean loss is 1.061467
# evaluate 69
# the correlation coeffizient is : 0.338876
# the mean loss is 0.995545
# evaluate 70
# the correlation coeffizient is : 0.298040
# the mean loss is 0.776696
# evaluate 71
# the correlation coeffizient is : 0.363636
# the mean loss is 0.815891
# evaluate 72
# the correlation coeffizient is : 0.402739
# the mean loss is 0.839296
# evaluate 73
# the correlation coeffizient is : 0.311510
# the mean loss is 0.808325
# evaluate 74
# the correlation coeffizient is : 0.373004
# the mean loss is 0.827292
# evaluate 75
# the correlation coeffizient is : 0.370721
# the mean loss is 0.814928
# evaluate 76
# the correlation coeffizient is : 0.403836
# the mean loss is 0.814373
# evaluate 77
# the correlation coeffizient is : 0.351141
# the mean loss is 1.110720
# evaluate 78
# the correlation coeffizient is : 0.345465
# the mean loss is 0.949461
# evaluate 79
# the correlation coeffizient is : 0.243121
# the mean loss is 1.009187
# evaluate 80
# the correlation coeffizient is : 0.359333
# the mean loss is 0.988002
# evaluate 81
# the correlation coeffizient is : 0.301488
# the mean loss is 0.900703
# evaluate 82
# the correlation coeffizient is : 0.333777
# the mean loss is 0.860392
# evaluate 83
# the correlation coeffizient is : 0.427322
# the mean loss is 0.870146
# evaluate 84
# the correlation coeffizient is : 0.423784
# the mean loss is 0.778160
# evaluate 85
# the correlation coeffizient is : 0.423715
# the mean loss is 0.780371
# evaluate 86
# the correlation coeffizient is : 0.432469
# the mean loss is 0.957008
# evaluate 87
# the correlation coeffizient is : 0.377135
# the mean loss is 0.919040
# evaluate 88
# the correlation coeffizient is : 0.271564
# the mean loss is 0.763352
# evaluate 89
# the correlation coeffizient is : 0.323260
# the mean loss is 0.755216
# evaluate 90
# the correlation coeffizient is : 0.353697
# the mean loss is 0.897173
# evaluate 91
# the correlation coeffizient is : 0.294449
# the mean loss is 0.809403
# evaluate 92
# the correlation coeffizient is : 0.264209
# the mean loss is 0.998396
# evaluate 93
# the correlation coeffizient is : 0.442020
# the mean loss is 0.804137
# evaluate 94
# the correlation coeffizient is : 0.416798
# the mean loss is 0.737473
# evaluate 95
# the correlation coeffizient is : 0.458779
# the mean loss is 0.987559
# evaluate 96
# the correlation coeffizient is : 0.304674
# the mean loss is 0.886954
# evaluate 97
# the correlation coeffizient is : 0.271666
# the mean loss is 0.907269
# evaluate 98
# the correlation coeffizient is : 0.402832
# the mean loss is 0.812214
# evaluate 99
# the correlation coeffizient is : 0.375330
# the mean loss is 0.878019
# evaluate 100
# the correlation coeffizient is : 0.413431
# the mean loss is 0.719401
# evaluate 101
# the correlation coeffizient is : 0.402797
# the mean loss is 0.931927
# evaluate 102
# the correlation coeffizient is : 0.316273
# the mean loss is 0.840161
# evaluate 103
# the correlation coeffizient is : 0.385787
# the mean loss is 0.806895
# evaluate 104
# the correlation coeffizient is : 0.431918
# the mean loss is 1.098621
# evaluate 105
# the correlation coeffizient is : 0.344195
# the mean loss is 0.980236
# evaluate 106
# the correlation coeffizient is : 0.319032
# the mean loss is 0.790329
# evaluate 107
# the correlation coeffizient is : 0.406937
# the mean loss is 0.907764
# evaluate 108
# the correlation coeffizient is : 0.383398
# the mean loss is 0.870537
# evaluate 109
# the correlation coeffizient is : 0.364440
# the mean loss is 0.888852
# evaluate 110
# the correlation coeffizient is : 0.357772
# the mean loss is 1.028347
# evaluate 111
# the correlation coeffizient is : 0.297779
# the mean loss is 0.844832
# evaluate 112
# the correlation coeffizient is : 0.423904
# the mean loss is 0.783399
# the correlation coeffizient is : 0.317991
# the correlation coeffizient is : 0.294938
# the correlation coeffizient is : 0.493380
# the correlation coeffizient is : 0.449230
# the correlation coeffizient is : 0.504435
# the correlation coeffizient is : 0.340281
# the correlation coeffizient is : 0.308568
# the correlation coeffizient is : 0.273896
# the correlation coeffizient is : 0.265416
# the correlation coeffizient is : 0.323982
# 0.64278840092910028

# %%
library(ggplot2)
loss = read.table('../data/MasterArbeit/mid_result/loss', header = FALSE, sep = ',')
corr = read.table('../data/MasterArbeit/mid_result/corr', header = FALSE, sep = ',')

# %%
p_corr = ggplot(corr, aes(x = V1, y = V2))
p_corr + geom_point() + xlab("number of batch") + ylab("corr") + ylim(0.0, 1.0)
# Out:
# plot without title

# %%
idea: nicht alle Demensionen in hidden value vector sind für die evaluation wichtig. 
MaskedModel1 (
  (li_mask): Linear (500 -> 500)
  (sf): Softmax ()
  (li_1): Linear (500 -> 10)
  (act_func): Tanh ()
  (li_out): Linear (10 -> 1)
)

# %%
opt = Params.Params()
pas = {'dim2': 10, 'act_func_out': None, 'tgt': '../data/MasterArbeit/data/data_scores', 'src_sys': '../data/MasterArbeit/test/train_sys_hidden', 'src_ref': '../data/MasterArbeit/test/train_ref_hidden', 'val_tgt': '../data/MasterArbeit/test/val_scores', 'src_val_sys': '../data/MasterArbeit/test/val_sys_hidden', 'src_val_ref': '../data/MasterArbeit/test/val_ref_hidden', 'test_tgt': '../data/MasterArbeit/test/test_scores', 'src_test_sys': '../data/MasterArbeit/test/test_sys_hidden', 'src_test_ref': '../data/MasterArbeit/test/test_ref_hidden', 'batch_size': 100, 'lr': 0.005592636698766986, 'act_func': 'Tanh', 'model': 'MaskedModel1'}
opt.set_params(pas)
fmin.o_func(pas)
# Out:
# ('act_func_out', None)
# ('tgt', '../data/MasterArbeit/data/data_scores')
# ('loss_fn', 'MSELoss')
# ('src_test_sys', '../data/MasterArbeit/test/test_sys_hidden')
# ('dim2', 10)
# ('dim3', None)
# ('val_tgt', '../data/MasterArbeit/test/val_scores')
# ('test_tgt', '../data/MasterArbeit/test/test_scores')
# ('weight_decay', 0)
# ('out', './test_data/pred')
# ('src_test_ref', '../data/MasterArbeit/test/test_ref_hidden')
# ('lr', 0.005592636698766986)
# ('act_func', 'Tanh')
# ('drop_out_rate', 0.5)
# ('momentum', 0.1)
# ('src_val_ref', '../data/MasterArbeit/test/val_ref_hidden')
# ('optim', 'Adam')
# ('batch_size', 100)
# ('src_val_sys', '../data/MasterArbeit/test/val_sys_hidden')
# ('src_sys', '../data/MasterArbeit/test/train_sys_hidden')
# ('src_ref', '../data/MasterArbeit/test/train_ref_hidden')
# ('eps', 1e-08)
# ('model', 'MaskedModel1')
# MaskedModel1 (
#   (li_mask): Linear (500 -> 500)
#   (sf): Softmax ()
#   (li_1): Linear (500 -> 10)
#   (act_func): Tanh ()
#   (li_out): Linear (10 -> 1)
# )
# number of batch is 75
# number of val batch 9
# number of test batch 9
# evaluate 0
# the correlation coeffizient is : 0.031823
# the mean loss is 0.993635
# evaluate 1
# the correlation coeffizient is : -0.179659
# the mean loss is 0.897888
# evaluate 2
# the correlation coeffizient is : 0.114482
# the mean loss is 0.969635
# evaluate 3
# the correlation coeffizient is : 0.160760
# the mean loss is 0.921243
# evaluate 4
# the correlation coeffizient is : 0.206764
# the mean loss is 0.929492
# evaluate 5
# the correlation coeffizient is : 0.204753
# the mean loss is 1.167442
# evaluate 6
# the correlation coeffizient is : 0.129115
# the mean loss is 1.066848
# evaluate 7
# the correlation coeffizient is : -0.015808
# the mean loss is 0.790844
# evaluate 8
# the correlation coeffizient is : 0.243834
# the mean loss is 0.909530
# evaluate 9
# the correlation coeffizient is : 0.160702
# the mean loss is 1.015579
# evaluate 10
# the correlation coeffizient is : 0.257160
# the mean loss is 0.857253
# evaluate 11
# the correlation coeffizient is : 0.331951
# the mean loss is 0.905601
# evaluate 12
# the correlation coeffizient is : 0.198977
# the mean loss is 0.887501
# evaluate 13
# the correlation coeffizient is : 0.224430
# the mean loss is 0.892032
# evaluate 14
# the correlation coeffizient is : 0.348665
# the mean loss is 1.104526
# evaluate 15
# the correlation coeffizient is : 0.265807
# the mean loss is 1.023232
# evaluate 16
# the correlation coeffizient is : 0.071921
# the mean loss is 0.781265
# evaluate 17
# the correlation coeffizient is : 0.320068
# the mean loss is 0.923698
# evaluate 18
# the correlation coeffizient is : 0.189711
# the mean loss is 0.975464
# evaluate 19
# the correlation coeffizient is : 0.275156
# the mean loss is 0.856158
# evaluate 20
# the correlation coeffizient is : 0.158239
# the mean loss is 0.940745
# evaluate 21
# the correlation coeffizient is : 0.228274
# the mean loss is 0.880469
# evaluate 22
# the correlation coeffizient is : 0.263019
# the mean loss is 0.869396
# evaluate 23
# the correlation coeffizient is : 0.319523
# the mean loss is 1.076208
# evaluate 24
# the correlation coeffizient is : 0.444264
# the mean loss is 0.934543
# evaluate 25
# the correlation coeffizient is : 0.076723
# the mean loss is 0.893257
# evaluate 26
# the correlation coeffizient is : 0.317077
# the mean loss is 0.885106
# evaluate 27
# the correlation coeffizient is : 0.231072
# the mean loss is 0.967005
# evaluate 28
# the correlation coeffizient is : 0.322101
# the mean loss is 0.800967
# evaluate 29
# the correlation coeffizient is : 0.302761
# the mean loss is 0.894248
# evaluate 30
# the correlation coeffizient is : 0.294782
# the mean loss is 0.850725
# evaluate 31
# the correlation coeffizient is : 0.383199
# the mean loss is 0.810100
# evaluate 32
# the correlation coeffizient is : 0.351407
# the mean loss is 1.066124
# evaluate 33
# the correlation coeffizient is : 0.478821
# the mean loss is 0.861081
# evaluate 34
# the correlation coeffizient is : 0.202741
# the mean loss is 0.809488
# evaluate 35
# the correlation coeffizient is : 0.264925
# the mean loss is 0.916377
# evaluate 36
# the correlation coeffizient is : 0.346610
# the mean loss is 0.891744
# evaluate 37
# the correlation coeffizient is : 0.342188
# the mean loss is 0.790124
# evaluate 38
# the correlation coeffizient is : 0.234868
# the mean loss is 0.934582
# evaluate 39
# the correlation coeffizient is : 0.364306
# the mean loss is 0.799853
# evaluate 40
# the correlation coeffizient is : 0.397214
# the mean loss is 0.789755
# evaluate 41
# the correlation coeffizient is : 0.372377
# the mean loss is 1.044233
# evaluate 42
# the correlation coeffizient is : 0.496238
# the mean loss is 0.831980
# evaluate 43
# the correlation coeffizient is : 0.279701
# the mean loss is 0.765419
# evaluate 44
# the correlation coeffizient is : 0.274640
# the mean loss is 0.901027
# evaluate 45
# the correlation coeffizient is : 0.309559
# the mean loss is 0.910740
# evaluate 46
# the correlation coeffizient is : 0.313189
# the mean loss is 0.858666
# evaluate 47
# the correlation coeffizient is : 0.274171
# the mean loss is 0.915150
# evaluate 48
# the correlation coeffizient is : 0.372293
# the mean loss is 0.794913
# evaluate 49
# the correlation coeffizient is : 0.418026
# the mean loss is 0.776124
# evaluate 50
# the correlation coeffizient is : 0.359438
# the mean loss is 1.034384
# evaluate 51
# the correlation coeffizient is : 0.491300
# the mean loss is 0.822668
# evaluate 52
# the correlation coeffizient is : 0.326542
# the mean loss is 0.736951
# evaluate 53
# the correlation coeffizient is : 0.318533
# the mean loss is 0.854166
# evaluate 54
# the correlation coeffizient is : 0.342460
# the mean loss is 0.943112
# evaluate 55
# the correlation coeffizient is : 0.325281
# the mean loss is 0.828653
# evaluate 56
# the correlation coeffizient is : 0.295284
# the mean loss is 0.917461
# evaluate 57
# the correlation coeffizient is : 0.384801
# the mean loss is 0.790760
# evaluate 58
# the correlation coeffizient is : 0.423945
# the mean loss is 0.775001
# evaluate 59
# the correlation coeffizient is : 0.353432
# the mean loss is 1.035944
# evaluate 60
# the correlation coeffizient is : 0.464080
# the mean loss is 0.842716
# evaluate 61
# the correlation coeffizient is : 0.355183
# the mean loss is 0.704922
# evaluate 62
# the correlation coeffizient is : 0.354418
# the mean loss is 0.832226
# evaluate 63
# the correlation coeffizient is : 0.345927
# the mean loss is 0.924737
# evaluate 64
# the correlation coeffizient is : 0.336025
# the mean loss is 0.825096
# evaluate 65
# the correlation coeffizient is : 0.315601
# the mean loss is 0.897540
# evaluate 66
# the correlation coeffizient is : 0.397431
# the mean loss is 0.787949
# evaluate 67
# the correlation coeffizient is : 0.435439
# the mean loss is 0.814055
# evaluate 68
# the correlation coeffizient is : 0.297636
# the mean loss is 1.086468
# evaluate 69
# the correlation coeffizient is : 0.450572
# the mean loss is 0.851259
# evaluate 70
# the correlation coeffizient is : 0.310109
# the mean loss is 0.713866
# evaluate 71
# the correlation coeffizient is : 0.339447
# the mean loss is 0.868421
# evaluate 72
# the correlation coeffizient is : 0.368649
# the mean loss is 0.879061
# evaluate 73
# the correlation coeffizient is : 0.336209
# the mean loss is 0.853316
# evaluate 74
# the correlation coeffizient is : 0.333407
# the mean loss is 0.886721
# evaluate 75
# the correlation coeffizient is : 0.384657
# the mean loss is 0.822111
# evaluate 76
# the correlation coeffizient is : 0.442495
# the mean loss is 0.767231
# evaluate 77
# the correlation coeffizient is : 0.292248
# the mean loss is 1.106250
# evaluate 78
# the correlation coeffizient is : 0.465050
# the mean loss is 0.846624
# evaluate 79
# the correlation coeffizient is : 0.348480
# the mean loss is 0.723724
# evaluate 80
# the correlation coeffizient is : 0.402783
# the mean loss is 0.795452
# evaluate 81
# the correlation coeffizient is : 0.317333
# the mean loss is 0.955894
# evaluate 82
# the correlation coeffizient is : 0.294770
# the mean loss is 0.862016
# evaluate 83
# the correlation coeffizient is : 0.324897
# the mean loss is 0.897201
# evaluate 84
# the correlation coeffizient is : 0.376545
# the mean loss is 0.827230
# evaluate 85
# the correlation coeffizient is : 0.426315
# the mean loss is 0.767812
# evaluate 86
# the correlation coeffizient is : 0.314297
# the mean loss is 1.101526
# evaluate 87
# the correlation coeffizient is : 0.470198
# the mean loss is 0.845543
# evaluate 88
# the correlation coeffizient is : 0.340328
# the mean loss is 0.729983
# evaluate 89
# the correlation coeffizient is : 0.413636
# the mean loss is 0.791837
# evaluate 90
# the correlation coeffizient is : 0.335362
# the mean loss is 0.931636
# evaluate 91
# the correlation coeffizient is : 0.311678
# the mean loss is 0.849187
# evaluate 92
# the correlation coeffizient is : 0.323037
# the mean loss is 0.944717
# evaluate 93
# the correlation coeffizient is : 0.387145
# the mean loss is 0.800613
# evaluate 94
# the correlation coeffizient is : 0.442000
# the mean loss is 0.761909
# evaluate 95
# the correlation coeffizient is : 0.347121
# the mean loss is 1.064901
# evaluate 96
# the correlation coeffizient is : 0.492617
# the mean loss is 0.809159
# evaluate 97
# the correlation coeffizient is : 0.334391
# the mean loss is 0.729851
# evaluate 98
# the correlation coeffizient is : 0.404010
# the mean loss is 0.809200
# evaluate 99
# the correlation coeffizient is : 0.358038
# the mean loss is 0.881373
# evaluate 100
# the correlation coeffizient is : 0.297180
# the mean loss is 0.957594
# evaluate 101
# the correlation coeffizient is : 0.357993
# the mean loss is 0.887333
# evaluate 102
# the correlation coeffizient is : 0.382352
# the mean loss is 0.798622
# evaluate 103
# the correlation coeffizient is : 0.449359
# the mean loss is 0.753502
# evaluate 104
# the correlation coeffizient is : 0.371962
# the mean loss is 1.030644
# evaluate 105
# the correlation coeffizient is : 0.431004
# the mean loss is 0.876974
# evaluate 106
# the correlation coeffizient is : 0.308377
# the mean loss is 0.819387
# evaluate 107
# the correlation coeffizient is : 0.399180
# the mean loss is 0.799471
# evaluate 108
# the correlation coeffizient is : 0.323843
# the mean loss is 0.941346
# evaluate 109
# the correlation coeffizient is : 0.289534
# the mean loss is 0.973821
# evaluate 110
# the correlation coeffizient is : 0.359886
# the mean loss is 0.882286
# evaluate 111
# the correlation coeffizient is : 0.413306
# the mean loss is 0.789104
# evaluate 112
# the correlation coeffizient is : 0.429884
# the mean loss is 0.764961
# the correlation coeffizient is : 0.388371
# the correlation coeffizient is : 0.342765
# the correlation coeffizient is : 0.344328
# the correlation coeffizient is : 0.472115
# the correlation coeffizient is : 0.433548
# the correlation coeffizient is : 0.212519
# the correlation coeffizient is : 0.352348
# the correlation coeffizient is : 0.276112
# the correlation coeffizient is : 0.207413
# the correlation coeffizient is : 0.388371
# 0.65821116538360724

# %%
library(ggplot2)
loss = read.table('../data/MasterArbeit/mid_result/loss', header = FALSE, sep = ',')
corr = read.table('../data/MasterArbeit/mid_result/corr', header = FALSE, sep = ',')

# %%
p_corr = ggplot(corr, aes(x = V1, y = V2))
p_corr + geom_point() + xlab("number of batch") + ylab("corr") + ylim(0.0, 1.0)
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title
